# %%
# Binary classification using Deep Neural Networks Example: Classify movie
#  reviews into positive" reviews and "negative" reviews, just based on the text content of the reviews.Use
#  IMDB datase

# %%
import numpy as np
from keras.datasets import imdb
from keras import models, layers
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 import numpy as np
# ----> 2 from tensorflow.keras.datasets import imdb
#       3 from tensorflow.keras import models, layers
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
# Load IMDB dataset (only top 10,000 most frequent words)
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=10000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Load IMDB dataset (only top 10,000 most frequent words)
# ----> 2 (x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=10000)
#
# NameError: name 'imdb' is not defined

# %%
# Convert sequences of word indices into binary vector form
def vectorize(sequences, dim=10000):
    result = np.zeros((len(sequences), dim))
    for i, seq in enumerate(sequences):
        result[i, seq] = 1
    return result

x_train = vectorize(x_train)
x_test = vectorize(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 8
#       5         result[i, seq] = 1
#       6     return result
# ----> 8 x_train = vectorize(x_train)
#       9 x_test = vectorize(x_test)
#
# NameError: name 'x_train' is not defined

# %%
# Define a simple deep neural network model
model = models.Sequential([
    layers.Input(shape=(10000,)),  # Explicit input layer
    layers.Dense(16, activation='relu'),
   
    layers.Dense(1, activation='sigmoid')
])

# %%
# Compile the model with appropriate optimizer, loss function, and metric
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the model on training data with a validation split
model.fit(x_train, y_train, epochs=5, batch_size=512, validation_split=0.2)
# Out:
# Epoch 1/5
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.7222 - loss: 0.5930 - val_accuracy: 0.8772 - val_loss: 0.3781
# Epoch 2/5
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8954 - loss: 0.3273 - val_accuracy: 0.8848 - val_loss: 0.3085
# Epoch 3/5
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9243 - loss: 0.2400 - val_accuracy: 0.8880 - val_loss: 0.2843
# Epoch 4/5
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9369 - loss: 0.2021 - val_accuracy: 0.8910 - val_loss: 0.2760
# Epoch 5/5
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9496 - loss: 0.1667 - val_accuracy: 0.8908 - val_loss: 0.2750

# %%
# Evaluate the model on test data
results = model.evaluate(x_test, y_test)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8833 - loss: 0.2899
